# %%
import os
import wget
import time
import requests
import csv
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup

project_path = os.path.abspath(os.path.dirname('__file__'))
driver_path = os.path.join(project_path, "chromedriver")
driver = webdriver.Chrome(driver_path)
driver.get('https://search.damai.cn/search.htm?spm=a2oeg.home.category.ditem_1.591b23e1yDqddL&ctl=%E8%AF%9D%E5%89%A7%E6%AD%8C%E5%89%A7&order=1&cty=%E4%B8%8A%E6%B5%B7')


header = ['Picture','Title', 'Venue', 'Time', 'Price','Link']
data = []

for i in range(1,4):
    html = driver.page_source
    soup = BeautifulSoup(html)
    for item in soup.find_all("div", attrs = {"class":"items"}):
        Picture = item.find("img", attrs = {"alt":"项目图片"}).get("src")
        Title = item.find ("div", attrs = {"class":"items__txt__title"}).text.strip()
        Venue = item.find ("div", attrs = {"class":"items__txt__time"}).text.strip()
        Time1 = item.find ("a", attrs = {"class":"items__txt__time__icon"})
        for el in Time1.find_parents("div",attrs = {"class":"items__txt__time"}):
            Time = el.get_text().strip()
        Price = item.find ("div", attrs = {"class":"items__txt__price"}).find("span").text.replace("\n"," ").strip()
        Link = item.find("div",attrs = {"class":"items__txt__title"}).find("a").get("href")
        data.append((Picture,Title,Venue,Time,Price,Link))
    searchBtn = driver.find_element_by_class_name('btn-next')
    searchBtn.click()
driver.quit()
df = pd.DataFrame(data, columns = header)
df.to_csv('Dramas.csv',sep=',', encoding = 'utf_8_sig')
df
# Out:
#                                               Picture  \
# 0   //img.alicdn.com/bao/uploaded/https://img.alic...
# 1   //img.alicdn.com/bao/uploaded/https://img.alic...
# 2   //img.alicdn.com/bao/uploaded/https://img.alic...
# 3   //img.alicdn.com/tfs/TB1S_dkRQvoK1RjSZFNXXcxMV...
# 4   //img.alicdn.com/tfs/TB1S_dkRQvoK1RjSZFNXXcxMV...
# ..                                                ...
# 85  //img.alicdn.com/tfs/TB1S_dkRQvoK1RjSZFNXXcxMV...
# 86  //img.alicdn.com/bao/uploaded/https://img.alic...
# 87  //img.alicdn.com/bao/uploaded/https://img.alic...
# 88  //img.alicdn.com/bao/uploaded/https://img.alic...
# 89  //img.alicdn.com/bao/uploaded/https://img.alic...
#
#                            Title                   Venue  \
# 0               【上海】 音乐剧《阿加莎》中文版              上海 | 中国大戏院
# 1                 【上海】 迪士尼嘉年华音乐会          上海 | 上海大剧院-大剧场
# 2       【上海】 中国国家话剧院经典话剧呈现《四世同堂》           上海 | 上汽上海文化广场
# 3        【上海】 集装箱沉浸式感官戏剧 《消失的航班》          上海 | BFC外滩金融中心
# 4         【上海】 缪时客出品  音乐剧《沉默的真相》  上海 | FANCL艺术中心 艺海剧院大剧场
# ..                           ...                     ...
# 85          【上海】 百老汇音乐剧《摇滚年代》中文版  上海 | FANCL艺术中心 艺海剧院大剧场
# 86          【上海】 赖声川经典《暗恋桃花源》专属版                上海 | 上剧场
# 87      【上海】 老舍经典·方旭导演作品 话剧《牛天赐》         上海 | 东方艺术中心-歌剧厅
# 88  【上海】 原创音乐剧 《 Amanda 的三十八岁生日》              上海 | 白玉兰剧场
# 89                【上海】 话剧《借问汤先生》        上海 | 橙剧场·可当代艺术中心
#
#                      Time                   Price  \
# 0   2021.12.22-2022.01.16   180-680             元
# 1        2022.01.15-01.16  180-1080             元
# 2        2022.01.21-01.23    80-880             元
# 3        2021.11.22-12.12    68-128             元
# 4   2021.12.30-2022.01.23   180-680             元
# ..                    ...                     ...
# 85       2021.12.22-12.26   180-680             元
# 86       2022.02.17-02.27   100-800             元
# 87  2021.12.31-2022.01.01   180-880             元
# 88       2021.12.22-12.24   100-200             元
# 89       2021.11.26-11.28   120-280             元
#
#                                                  Link
# 0   //detail.damai.cn/item.htm?id=660147957844&cli...
# 1   //detail.damai.cn/item.htm?id=660772221330&cli...
# 2   //detail.damai.cn/item.htm?id=661006498699&cli...
# 3   //detail.damai.cn/item.htm?id=659519464426&cli...
# 4   //detail.damai.cn/item.htm?id=660350446389&cli...
# ..                                                ...
# 85  //detail.damai.cn/item.htm?id=657420801692&cli...
# 86  //detail.damai.cn/item.htm?id=656159964276&cli...
# 87  //detail.damai.cn/item.htm?id=659649359413&cli...
# 88  //detail.damai.cn/item.htm?id=660482443493&cli...
# 89  //detail.damai.cn/item.htm?id=661160183827&cli...
#
# [90 rows x 6 columns]

# %%
from IPython.display import HTML

# %%
from IPython.core.display import HTML

# %%
HTML('index')
# Out:
# index

# %%
HTML('index.html')

# %%
f = open('index.html', 'w')
